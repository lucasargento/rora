# %%
# %load_ext autoreload
# %autoreload 2

from src.agent.agent import build_agent

# %%
my_key = "your api key"

agent = build_agent(
    api_key=my_key,
    model="o3-mini-2025-01-31",
)

# %%
# Example invocation with optimization problem statement
initial_state = {
    "problem_statement": "Minimize 3x + 2y subject to x + y >= 10, x >= 0, y >= 0",
    "problem_name": "dummydemo_2",
    "expected_output": "Expected solution: x = 0, y = 10\nOptimal objective value: 20",
    "coherent": True,
    "execution_error": False
}

state = agent.invoke(initial_state)
# Out:
# 📐 [DEBUG] expert_math_agent: Starting mathematical formulation
# ------------------------------------------------------------------------------------------------------------------------
# --> Problem Description
# Minimize 3x + 2y subject to x + y >= 10, x >= 0, y >= 0
# ........................................................................................................................
# --> Mathematical Problem Formulation:
# Sets:
# - V: set of decision variables = {x, y}
#
# Parameters:
# - cost_x: cost per unit of x (3 monetary units per unit)
# - cost_y: cost per unit of y (2 monetary units per unit)
# - min_total: required minimum sum of x and y (10 units)
#   (Assumption: the units for x and y are consistent across the model)
#
# Variables:
# - x: amount of decision variable x (continuous, x ≥ 0, units are defined by the context)
# - y: amount of decision variable y (continuous, y ≥ 0, units are defined by the context)
#
# Objective:
# - Minimize total cost defined as TotalCost = cost_x * x + cost_y * y
#
# Constraints:
# 1. Sum constraint: Ensure that the sum of x and y meets the minimum requirement
#    - x + y ≥ min_total
# 2. Nonnegativity constraints:
#    - x ≥ 0
#    - y ≥ 0
#
# Comments:
# - The cost coefficients (3 and 2) are assumed to be in consistent monetary units (e.g., dollars per unit produced).
# - x and y are assumed to be continuous. If they should be integer-valued, adjust the variable type accordingly.
# - This model is a linear programming formulation suitable for implementation in Python or OR-Tools.
# ------------------------------------------------------------------------------------------------------------------------
# 💻 [DEBUG] expert_code_agent: Starting code implementation
# 💻 [DEBUG] expert_code_agent: Generated code implementation (length: 2036 chars)
# 🔍 [DEBUG] code_validator_node: Validating code
# 🔍 [DEBUG] code_validator_node: Validation result: VALID: Code passed basic validation checks
# 💻 [DEBUG] code_critic_agent: Starting code critic
# 💻 [DEBUG] code_critic_agent: Generated code feedback:
#  OK
# 🚀 [DEBUG] code_executor_node: Executing code
# 🚀 [DEBUG] code_executor_node: Execution result: SUCCESS:
# === Model Implementation using ortools.linear_solver ===
# Status: OPTIMAL
# Optimal objective value: 20.0
# x = 0.0
# y = 10.0
# ...
# 💻 [DEBUG] reflection_agent: Starting reflection step
# 💻 [DEBUG] reflection_agent: Generated solution reflection:
#  OK
# Succesfully reached a feasible solution, saving results.
