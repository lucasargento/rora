# %% [markdown]
# ### Import and build RORA

# %%
# %load_ext autoreload
# %autoreload 2

from src.agent.agent import build_agent

# %%
my_key = "your api key"

agent = build_agent(
    api_key=my_key,
    model="o3-mini-2025-01-31",
)

# %% [markdown]
# ### Test it on an optimization problem

# %%
my_problem = "Minimize 3x + 2y subject to x + y >= 10, x >= 0, y >= 0"
expected_output = "Expected solution: x = 0, y = 10\nOptimal objective value: 20"

# Example invocation with optimization problem statement
initial_state = {
    "problem_statement": my_problem,
    "problem_name": "demo_problem",
    "expected_output": expected_output,
    "coherent": True,
    "execution_error": False
}

state = agent.invoke(initial_state)
# Out:
# 📐 [DEBUG] expert_math_agent: Starting mathematical formulation
# ------------------------------------------------------------------------------------------------------------------------
# --> Problem Description
# Minimize 3x + 2y subject to x + y >= 10, x >= 0, y >= 0
# ........................................................................................................................
# --> Mathematical Problem Formulation:
# Sets:
# - No sets are required for this problem since decisions refer directly to the two variables.
#
# Parameters:
# - cost_x: cost coefficient for variable x, equal to 3 (monetary units per unit of x).
# - cost_y: cost coefficient for variable y, equal to 2 (monetary units per unit of y).
# - min_required_sum: minimum required sum for x and y, equal to 10 (units).
#
# Variables:
# - x: a continuous decision variable representing the first quantity; x must be greater than or equal to 0.
# - y: a continuous decision variable representing the second quantity; y must be greater than or equal to 0.
#
# Objective:
# - Minimize total cost defined as (cost_x * x) + (cost_y * y), that is, minimize 3x + 2y.
#   (The objective is expressed in monetary units.)
#
# Constraints:
# - Sum constraint: x + y must be greater than or equal to min_required_sum; that is, x + y >= 10.
# - Nonnegativity constraints:
#   - x >= 0
#   - y >= 0
#
# Comments:
# - All units are assumed to be consistent (monetary units for cost coefficients and unit counts for x and y).
# - Both decision variables are continuous; if integer decisions are required in a specific application, they should be explicitly declared as integers.
# - This formulation is directly implementable in optimization libraries such as OR-Tools or similar, using the defined parameters and variables.
# ------------------------------------------------------------------------------------------------------------------------
# 💻 [DEBUG] expert_code_agent: Starting code implementation
# 💻 [DEBUG] expert_code_agent: Generated code implementation (length: 3454 chars)
# 🔍 [DEBUG] code_validator_node: Validating code
# 🔍 [DEBUG] code_validator_node: Validation result: VALID: Code passed basic validation checks
# 💻 [DEBUG] code_critic_agent: Starting code critic
# 💻 [DEBUG] code_critic_agent: Generated code feedback:
#  OK
# 🚀 [DEBUG] code_executor_node: Executing code
# 🚀 [DEBUG] code_executor_node: Execution result: SUCCESS:
# === Continuous Model (using GLOP) ===
# Optimal solution found:
#   x = 0.0
#   y = 10.0
#   Objective value = 20.0
#
# === Integer Model (using CBC) ===
# Optimal solution found:
#   x = 0.0
#   y = 10.0
#   Objective value = 20.0
# ...
# 💻 [DEBUG] reflection_agent: Starting reflection step
# 💻 [DEBUG] reflection_agent: Generated solution reflection:
#  OK
# Succesfully reached a feasible solution, saving results.
